# %% [markdown]
# # Eksperimen Q-Learning Scenario A
#
# State: `(current_node,)` — agen hanya mengetahui node saat ini.
#
# Notebook ini tidak menduplikasi implementasi. Semua konfigurasi, download/load OSM, environment, reward, Q-Learning, metrik, grafik, dan peta berasal dari `rute_lari_core.py`.

# %%
# %pip install -q "osmnx>=2.0" networkx numpy pandas geopandas shapely folium matplotlib pyproj
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Muat graf dengan core bersama
#
# Jika GraphML belum ada, fungsi berikut mengunduh data OSM dengan konfigurasi yang sama seperti notebook analisis. Jika sudah ada, GraphML dimuat tanpa mengunduh ulang.

# %%
import importlib
import rute_lari_core

# Memuat ulang core agar perubahan grafik terbaru terbaca tanpa restart kernel.
importlib.reload(rute_lari_core)

from rute_lari_core import (
    load_or_download_graph,
    run_scenario_experiment,
    EPISODES,
    SEEDS,
)

G, START_NODE, GRAPH_PATH, downloaded_now = load_or_download_graph()

print(f'Graf: {G.number_of_nodes():,} node, {G.number_of_edges():,} edge')
print(f'Node start: {START_NODE}')
print(f'GraphML: {GRAPH_PATH}')
print('Sumber graf:', 'download baru' if downloaded_now else 'GraphML yang sudah ada')
print(f'Training: {len(SEEDS)} seed × {EPISODES:,} episode')
# Out:
# Graf: 8,027 node, 21,374 edge
# Node start: 1720975931
# GraphML: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/data_osm_5km/graf_jalan_kaki_5km.graphml
# Sumber graf: GraphML yang sudah ada
# Training: 5 seed × 2,500 episode

# %% [markdown]
# ## 2. Eksperimen sensitivitas dengan epsilon dinamis
#
# Bagian ini mempertahankan eksperimen awal Scenario A. Setiap cell melatih ulang lima seed dari awal; graf, reward, penyaringan ruas legal, state, seed, dan evaluasi greedy sama. Pada bagian ini epsilon turun dari 1,00 ke 0,05 selama **seluruh** jumlah episode training. Karena itu hasil 10k--50k dipakai sebagai eksplorasi awal, bukan pembandingan final antar durasi training.
#
# Jalankan cell secara berurutan. Eksperimen lengkap mencakup 5 seed × (10.000 + 20.000 + 30.000 + 40.000 + 50.000) = 750.000 episode untuk Scenario A. Artefak setiap percobaan disimpan pada folder terpisah agar tidak saling menimpa.

# %% [markdown]
# ### 2.1 Training 10.000 episode

# %%
import importlib
# Memastikan kernel memakai versi core terbaru yang mendukung parameter episodes.
importlib.reload(rute_lari_core)

result_a_10000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A', episodes=10_000,
    result_subdir='sensitivitas_episode_10000_A',
)

# %% [markdown]
# ### 2.2 Training 20.000 episode

# %%
import importlib
# Memastikan kernel memakai versi core terbaru yang mendukung parameter episodes.
importlib.reload(rute_lari_core)

result_a_20000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A', episodes=20_000,
    result_subdir='sensitivitas_episode_20000_A',
)

# %% [markdown]
# ### 2.3 Training 30.000 episode

# %%
import importlib
# Memastikan kernel memakai versi core terbaru yang mendukung parameter episodes.
importlib.reload(rute_lari_core)

result_a_30000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A', episodes=30_000,
    result_subdir='sensitivitas_episode_30000_A',
)

# %% [markdown]
# ### 2.4 Training 40.000 episode

# %%
import importlib
# Memastikan kernel memakai versi core terbaru yang mendukung parameter episodes.
importlib.reload(rute_lari_core)

result_a_40000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A', episodes=40_000,
    result_subdir='sensitivitas_episode_40000_A',
)

# %% [markdown]
# ### 2.5 Training 50.000 episode

# %%
import importlib
# Memastikan kernel memakai versi core terbaru yang mendukung parameter episodes.
importlib.reload(rute_lari_core)

result_a_50000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A', episodes=50_000,
    result_subdir='sensitivitas_episode_50000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 50,000 episode
# seed=0: over_distance, 5.60 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.52 km, is_loop=False
# seed=3: over_distance, 5.51 km, is_loop=False
# seed=4: over_distance, 5.60 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5598.521483    5511.675315    5517.275918
# absolute_distance_error_m      598.521483     511.675315     517.275918
# total_reward                   -74.970748     -76.940963    -133.848368
# mean_comfort                     0.730868       0.720767       0.755886
# return_progress_ratio             0.26087       0.258621           0.46
# distance_to_start_at_end_m    1452.149463    1135.978365    1593.843056
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5505.994521    5600.680616
# absolute_distance_error_m      505.994521     600.680616
# total_reward                    -61.31648     -87.449833
# mean_comfort                     0.700994       0.651502
# return_progress_ratio                0.26            0.2
# distance_to_start_at_end_m    1685.626997    2598.648799
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 3
# Metrik: is_loop=False, jarak=5505.99 m, galat=505.99 m, comfort=0.701, return_progress=0.260, jarak akhir ke start=1685.63 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f4fa64b1f3f1f71fbf260b65c414682 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f4fa64b1f3f1f71fbf260b65c414682&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f4fa64b1f3f1f71fbf260b65c414682 = L.map(
#                 &quot;map_1f4fa64b1f3f1f71fbf260b65c414682&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1f4fa64b1f3f1f71fbf260b65c414682);
#
#
#
#
#
#             var tile_layer_153c0b6560c2eac5b4253329e9b99563 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_153c0b6560c2eac5b4253329e9b99563.addTo(map_1f4fa64b1f3f1f71fbf260b65c414682);
#
#
#             var poly_line_c19c746dc1184df720496d514a64404f = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_1f4fa64b1f3f1f71fbf260b65c414682);
#
#
#             poly_line_c19c746dc1184df720496d514a64404f.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_e661f33b127514ac1b2e17598de84115 = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_1f4fa64b1f3f1f71fbf260b65c414682);
#
#
#             poly_line_e661f33b127514ac1b2e17598de84115.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_75a71824fc555f4afd28669a732118f7 = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.283325800000009, 112.7096456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_1f4fa64b1f3f1f71fbf260b65c414682);
#
#
#             poly_line_75a71824fc555f4afd28669a732118f7.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_e5ce3d082e28217acf975d8bad037113 = L.polyline(
#                 [[-7.283325800000009, 112.7096456], [-7.2829505, 112.7084163], [-7.282942300000005, 112.7083891], [-7.282935600000001, 112.7083576]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_1f4fa64b1f3f1f71
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 2.6 Ringkasan perbandingan
#
# Tabel dan grafik berikut memakai evaluasi greedy lima seed dari setiap jumlah episode. `success_rate_greedy` adalah proporsi seed yang membentuk loop valid. Bandingkan terutama keberhasilan loop, galat jarak, return progress ratio, dan peluang closing action tersedia.

# %%
import matplotlib.pyplot as plt
import pandas as pd

episode_results = {
    10_000: result_a_10000,
    20_000: result_a_20000,
    30_000: result_a_30000,
    40_000: result_a_40000,
    50_000: result_a_50000,
}

summary_rows = []
for episodes, result in episode_results.items():
    metrics = result['metrics']
    summary_rows.append({
        'episodes': episodes,
        'success_rate_greedy': metrics['is_loop'].mean(),
        'mean_distance_error_m': metrics['absolute_distance_error_m'].mean(),
        'mean_total_reward': metrics['total_reward'].mean(),
        'mean_comfort': metrics['mean_comfort'].mean(),
        'mean_return_progress_ratio': metrics['return_progress_ratio'].mean(),
        'closing_action_available_rate': metrics['closing_action_available'].mean(),
    })

episode_sensitivity_df = pd.DataFrame(summary_rows).sort_values('episodes')
display(episode_sensitivity_df)

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
plots = [
    ('success_rate_greedy', 'Keberhasilan Loop pada Evaluasi Greedy', 'Proporsi seed'),
    ('mean_distance_error_m', 'Rata-rata Galat Jarak', 'Meter'),
    ('mean_return_progress_ratio', 'Rata-rata Return Progress Ratio', 'Proporsi langkah'),
    ('closing_action_available_rate', 'Peluang Closing Action Tersedia', 'Proporsi seed'),
]
for axis, (column, title, ylabel) in zip(axes.flat, plots):
    axis.plot(episode_sensitivity_df['episodes'], episode_sensitivity_df[column], marker='o')
    axis.set(title=title, xlabel='Jumlah episode training', ylabel=ylabel)
    axis.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Sensitivitas lanjutan dengan epsilon decay tetap
#
# "
#             f"Bagian ini menguji Scenario A pada 50.000, 100.000, 200.000, dan 400.000 episode. Semua percobaan memakai `epsilon_decay_episodes=50_000`: epsilon turun dari 1,00 ke 0,05 hanya pada 50.000 episode pertama, lalu tetap 0,05 sampai training selesai.
#
# "
#             f"Dengan desain ini, perbedaan hasil 50k, 100k, 200k, dan 400k dapat dibaca sebagai dampak tambahan durasi training setelah fase eksplorasi utama selesai. Setiap cell tetap melatih lima seed dari awal dan menyimpan artefak pada folder yang berbeda. Training 50k dijalankan ulang agar rangkaian ini mandiri dan dapat direproduksi, walaupun jadwal epsilon-nya secara matematis sama dengan eksperimen dinamis 50k.

# %% [markdown]
# ### 3.1 Training 50,000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar parameter epsilon_decay_episodes versi terbaru digunakan.
importlib.reload(rute_lari_core)

result_a_fixed_50000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=50_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_50000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 50,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.60 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.52 km, is_loop=False
# seed=3: over_distance, 5.51 km, is_loop=False
# seed=4: over_distance, 5.60 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5598.521483    5511.675315    5517.275918
# absolute_distance_error_m      598.521483     511.675315     517.275918
# total_reward                   -74.970748     -76.940963    -133.848368
# mean_comfort                     0.730868       0.720767       0.755886
# return_progress_ratio             0.26087       0.258621           0.46
# distance_to_start_at_end_m    1452.149463    1135.978365    1593.843056
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5505.994521    5600.680616
# absolute_distance_error_m      505.994521     600.680616
# total_reward                    -61.31648     -87.449833
# mean_comfort                     0.700994       0.651502
# return_progress_ratio                0.26            0.2
# distance_to_start_at_end_m    1685.626997    2598.648799
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 3
# Metrik: is_loop=False, jarak=5505.99 m, galat=505.99 m, comfort=0.701, return_progress=0.260, jarak akhir ke start=1685.63 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fbab2908ad4d9dcb9496ffb509eddae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fbab2908ad4d9dcb9496ffb509eddae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fbab2908ad4d9dcb9496ffb509eddae = L.map(
#                 &quot;map_4fbab2908ad4d9dcb9496ffb509eddae&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4fbab2908ad4d9dcb9496ffb509eddae);
#
#
#
#
#
#             var tile_layer_747d8aa398dfae5c026d8e5c9ee0921d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_747d8aa398dfae5c026d8e5c9ee0921d.addTo(map_4fbab2908ad4d9dcb9496ffb509eddae);
#
#
#             var poly_line_691ae5d3c00d70aeb01c655aebfc6314 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_4fbab2908ad4d9dcb9496ffb509eddae);
#
#
#             poly_line_691ae5d3c00d70aeb01c655aebfc6314.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_9bc4e8bf2decfeb36d035ff21603fb0a = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_4fbab2908ad4d9dcb9496ffb509eddae);
#
#
#             poly_line_9bc4e8bf2decfeb36d035ff21603fb0a.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_e2d19133a022b57d25cd8625c7b5f028 = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.283325800000009, 112.7096456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_4fbab2908ad4d9dcb9496ffb509eddae);
#
#
#             poly_line_e2d19133a022b57d25cd8625c7b5f028.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_2597341aa700e95caf20e73ca86c6121 = L.polyline(
#                 [[-7.283325800000009, 112.7096456], [-7.2829505, 112.7084163], [-7.282942300000005, 112.7083891], [-7.282935600000001, 112.7083576]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_4fbab2908ad4d9dc
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.2 Training 100,000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar parameter epsilon_decay_episodes versi terbaru digunakan.
importlib.reload(rute_lari_core)

result_a_fixed_100000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=100_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_100000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 100,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.73 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.53 km, is_loop=False
# seed=3: over_distance, 5.52 km, is_loop=False
# seed=4: over_distance, 5.54 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5732.485047     5510.75518    5531.362393
# absolute_distance_error_m      732.485047      510.75518     531.362393
# total_reward                  -261.091273     -40.743483     -79.355164
# mean_comfort                      0.71793       0.698874       0.690386
# return_progress_ratio             0.54717       0.489796       0.101449
# distance_to_start_at_end_m     662.510729     124.594023    2911.277973
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5524.234762    5536.999203
# absolute_distance_error_m      524.234762     536.999203
# total_reward                   -52.042215     -58.972988
# mean_comfort                     0.734298       0.729398
# return_progress_ratio                0.75       0.316667
# distance_to_start_at_end_m     374.587921    1165.840124
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 1
# Metrik: is_loop=False, jarak=5510.76 m, galat=510.76 m, comfort=0.699, return_progress=0.490, jarak akhir ke start=124.59 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d6f8e18d16335ea10d6e8a7d23f5faa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d6f8e18d16335ea10d6e8a7d23f5faa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d6f8e18d16335ea10d6e8a7d23f5faa = L.map(
#                 &quot;map_5d6f8e18d16335ea10d6e8a7d23f5faa&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
#
#
#
#
#
#             var tile_layer_657e5a28cff854265e56b8aab5754c43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_657e5a28cff854265e56b8aab5754c43.addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
#
#
#             var poly_line_23e0223e6d0e8a34946e219226f7809a = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281896899999991, 112.7087177], [-7.281887599999994, 112.708668], [-7.281864900000004, 112.7085983]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
#
#
#             poly_line_23e0223e6d0e8a34946e219226f7809a.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_fd6c29bbaad0220732cb967719435692 = L.polyline(
#                 [[-7.281864900000004, 112.7085983], [-7.281595399999992, 112.7086674], [-7.281532099999991, 112.7086851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
#
#
#             poly_line_fd6c29bbaad0220732cb967719435692.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_387c2596d4dcb1e8219267cd4c07f79e = L.polyline(
#                 [[-7.281532099999991, 112.7086851], [-7.281107699999999, 112.7087868]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
#
#
#             poly_line_387c2596d4dcb1e8219267cd4c07f79e.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_c750a4c28183205dca98561dbf391d15 = L.polyline(
#                 [[-7.281107699999999, 112.7087868], [-7.2810654, 112.7086208]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_5d6f8e18d16335ea10d6e8a7d23f5faa);
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.3 Training 200,000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar parameter epsilon_decay_episodes versi terbaru digunakan.
importlib.reload(rute_lari_core)

result_a_fixed_200000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=200_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_200000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 200,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.53 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.64 km, is_loop=False
# seed=3: over_distance, 5.52 km, is_loop=False
# seed=4: over_distance, 5.51 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5527.088569    5508.152713    5641.129407
# absolute_distance_error_m      527.088569     508.152713     641.129407
# total_reward                   -89.616133     -46.932903     -94.194735
# mean_comfort                     0.752312       0.705589       0.714631
# return_progress_ratio            0.434783       0.210526       0.136364
# distance_to_start_at_end_m    1243.774779    1828.668801    2917.960748
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5521.958521    5511.376006
# absolute_distance_error_m      521.958521     511.376006
# total_reward                   -43.923649     -40.940026
# mean_comfort                     0.727937       0.707243
# return_progress_ratio            0.053571           0.54
# distance_to_start_at_end_m    2621.485829    1268.555416
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 1
# Metrik: is_loop=False, jarak=5508.15 m, galat=508.15 m, comfort=0.706, return_progress=0.211, jarak akhir ke start=1828.67 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04549b58a6a0b4f83f43d2ed4252fb69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04549b58a6a0b4f83f43d2ed4252fb69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04549b58a6a0b4f83f43d2ed4252fb69 = L.map(
#                 &quot;map_04549b58a6a0b4f83f43d2ed4252fb69&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#
#
#
#             var tile_layer_bd752953dfb6714b08bc4e4741bd2d8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd752953dfb6714b08bc4e4741bd2d8c.addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#             var poly_line_2cd1e210bb740c18557a49e4ca3049a4 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281918399999998, 112.7100804]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#             poly_line_2cd1e210bb740c18557a49e4ca3049a4.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_e825e27d5c606d2c6f06bc72da5eabdd = L.polyline(
#                 [[-7.281918399999998, 112.7100804], [-7.281575100000001, 112.708849], [-7.281558999999994, 112.7087937], [-7.281532099999991, 112.7086851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#             poly_line_e825e27d5c606d2c6f06bc72da5eabdd.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_dc2b31f76cef8284afce3ad39a35c234 = L.polyline(
#                 [[-7.281532099999991, 112.7086851], [-7.281107699999999, 112.7087868]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#             poly_line_dc2b31f76cef8284afce3ad39a35c234.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_758655838670d6f7330023eff2d2dec3 = L.polyline(
#                 [[-7.281107699999999, 112.7087868], [-7.2810654, 112.7086208]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_04549b58a6a0b4f83f43d2ed4252fb69);
#
#
#             poly_line_
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_200000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.4 Training 400,000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar parameter epsilon_decay_episodes versi terbaru digunakan.
importlib.reload(rute_lari_core)

result_a_fixed_400000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=400_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_400000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 400,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.54 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.55 km, is_loop=False
# seed=3: over_distance, 5.63 km, is_loop=False
# seed=4: over_distance, 5.54 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5538.153216    5505.605749    5545.619425
# absolute_distance_error_m      538.153216     505.605749     545.619425
# total_reward                   -50.533735     -39.672928     -37.577665
# mean_comfort                     0.670527       0.698564       0.744946
# return_progress_ratio            0.280702       0.523077       0.491228
# distance_to_start_at_end_m    2400.208655     802.361299    1223.608774
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5626.992683    5542.567989
# absolute_distance_error_m      626.992683     542.567989
# total_reward                    -65.19576     -55.682513
# mean_comfort                     0.690144       0.712986
# return_progress_ratio            0.404255            0.5
# distance_to_start_at_end_m     968.747958     712.382928
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 1
# Metrik: is_loop=False, jarak=5505.61 m, galat=505.61 m, comfort=0.699, return_progress=0.523, jarak akhir ke start=802.36 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc4d602b8bebaa69e72c5a80892e0cd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc4d602b8bebaa69e72c5a80892e0cd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc4d602b8bebaa69e72c5a80892e0cd8 = L.map(
#                 &quot;map_cc4d602b8bebaa69e72c5a80892e0cd8&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cc4d602b8bebaa69e72c5a80892e0cd8);
#
#
#
#
#
#             var tile_layer_700de23e15df9dc411fbc47953cb2aed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_700de23e15df9dc411fbc47953cb2aed.addTo(map_cc4d602b8bebaa69e72c5a80892e0cd8);
#
#
#             var poly_line_c3516932f56a24a9e594b9c567d2d141 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_cc4d602b8bebaa69e72c5a80892e0cd8);
#
#
#             poly_line_c3516932f56a24a9e594b9c567d2d141.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_7daff71cd3f6b23aaac4a62b72fbcf37 = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_cc4d602b8bebaa69e72c5a80892e0cd8);
#
#
#             poly_line_7daff71cd3f6b23aaac4a62b72fbcf37.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_9a6c5f9d5b4f1d3abeaa1431500b127d = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.282955400000005, 112.7096781], [-7.282616799999996, 112.7085564], [-7.282600699999989, 112.7085125], [-7.282576600000001, 112.7084395]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_cc4d602b8bebaa69e72c5a80892e0cd8);
#
#
#             poly_line_9a6c5f9d5b4f1d3abeaa1431500b127d.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_52814b91900d4ffadb97fbfc31fa8c7f = L.polyline(
#                 [[-7.282576600000001, 112.7084395], [-7.2822282000000085, 112.7085184]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;:
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_400000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.5 Ringkasan epsilon decay tetap
#
# Tabel dan grafik berikut menggunakan evaluasi greedy lima seed dari setiap jumlah episode. Bandingkan terutama keberhasilan loop, galat jarak, return progress ratio, dan peluang closing action tersedia. TD-error dibaca dari grafik diagnosis masing-masing training, bukan dari tabel ringkasan ini.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Semua hasil di bawah memakai jadwal epsilon yang sama: turun selama 50.000
# episode pertama, lalu tetap 0,05. Karena itu perbedaan antar titik terutama
# berasal dari tambahan durasi training, bukan dari durasi eksplorasi yang berubah.
fixed_decay_results = {
    50_000: result_a_fixed_50000,
    100_000: result_a_fixed_100000,
    200_000: result_a_fixed_200000,
    400_000: result_a_fixed_400000,
}

summary_rows = []
for episodes, result in fixed_decay_results.items():
    metrics = result['metrics']
    summary_rows.append({
        'episodes': episodes,
        'epsilon_decay_episodes': result['epsilon_decay_episodes'],
        'success_rate_greedy': metrics['is_loop'].mean(),
        'mean_distance_error_m': metrics['absolute_distance_error_m'].mean(),
        'mean_total_reward': metrics['total_reward'].mean(),
        'mean_comfort': metrics['mean_comfort'].mean(),
        'mean_return_progress_ratio': metrics['return_progress_ratio'].mean(),
        'closing_action_available_rate': metrics['closing_action_available'].mean(),
    })

fixed_decay_sensitivity_df = pd.DataFrame(summary_rows).sort_values('episodes')
display(fixed_decay_sensitivity_df)

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
plots = [
    ('success_rate_greedy', 'Keberhasilan Loop pada Evaluasi Greedy', 'Proporsi seed'),
    ('mean_distance_error_m', 'Rata-rata Galat Jarak', 'Meter'),
    ('mean_return_progress_ratio', 'Rata-rata Return Progress Ratio', 'Proporsi langkah'),
    ('closing_action_available_rate', 'Peluang Closing Action Tersedia', 'Proporsi seed'),
]
for axis, (column, title, ylabel) in zip(axes.flat, plots):
    axis.plot(
        fixed_decay_sensitivity_df['episodes'],
        fixed_decay_sensitivity_df[column],
        marker='o',
    )
    axis.set(title=title, xlabel='Jumlah episode training', ylabel=ylabel)
    axis.grid(alpha=0.25)
plt.tight_layout()
plt.show()
# Out:
#    episodes  epsilon_decay_episodes  success_rate_greedy  \
# 0     50000                   50000                  0.0
# 1    100000                   50000                  0.0
# 2    200000                   50000                  0.0
# 3    400000                   50000                  0.0
#
#    mean_distance_error_m  mean_total_reward  mean_comfort  \
# 0             546.829571         -86.905278      0.712003
# 1             567.167317         -98.441025      0.714177
# 2             541.941043         -63.121489      0.721542
# 3             551.787812         -49.732520      0.703433
#
#    mean_return_progress_ratio  closing_action_available_rate
# 0                    0.287898                            0.0
# 1                    0.441016                            0.0
# 2                    0.275049                            0.0
# 3                    0.439852                            0.0

# %% [markdown]
# ## 4. Cara membaca hasil evaluasi
#
# Tabel evaluasi utama memuat `is_loop`, `total_distance_m`, `absolute_distance_error_m`, `total_reward`, `mean_comfort`, `return_progress_ratio`, `distance_to_start_at_end_m`, `closing_action_available`, dan `termination_reason`.
#
# Grafik diagnosis tetap membantu menjelaskan proses training, khususnya termination rate dan ketersediaan closing action.
#
# Baca detail seluruh implementasi di `IMPLEMENTASI.md`.

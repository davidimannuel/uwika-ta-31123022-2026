# %% [markdown]
# # Eksperimen Q-Learning Scenario A
#
# State: `(current_node,)` — agen hanya mengetahui node saat ini.
#
# Notebook ini tidak menduplikasi implementasi. Semua konfigurasi, download/load OSM, environment, reward, Q-Learning, metrik, grafik, dan peta berasal dari `rute_lari_core.py`.

# %%
# %pip install -q "osmnx>=2.0" networkx numpy pandas geopandas shapely folium matplotlib pyproj

# %% [markdown]
# ## 1. Muat graf dengan core bersama
#
# Jika GraphML belum ada, fungsi berikut mengunduh data OSM dengan konfigurasi yang sama seperti notebook analisis. Jika sudah ada, GraphML dimuat tanpa mengunduh ulang.

# %%
import importlib
import rute_lari_core

# Memuat ulang core agar perubahan grafik terbaru terbaca tanpa restart kernel.
importlib.reload(rute_lari_core)

from rute_lari_core import (
    load_or_download_graph,
    run_scenario_experiment,
    EPISODES,
    SEEDS,
)

G, START_NODE, GRAPH_PATH, downloaded_now = load_or_download_graph()

print(f'Graf: {G.number_of_nodes():,} node, {G.number_of_edges():,} edge')
print(f'Node start: {START_NODE}')
print(f'GraphML: {GRAPH_PATH}')
print('Sumber graf:', 'download baru' if downloaded_now else 'GraphML yang sudah ada')
print(f'Training: {len(SEEDS)} seed × {EPISODES:,} episode')
# Out:
# Graf: 8,027 node, 21,374 edge
# Node start: 1720975931
# GraphML: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/data_osm_5km/graf_jalan_kaki_5km.graphml
# Sumber graf: GraphML yang sudah ada
# Training: 5 seed × 10,000 episode

# %% [markdown]
# ## 2. Eksperimen pendahuluan: epsilon decay dinamis
#
# Pada Scenario A, epsilon turun dari 1,00 ke 0,05 selama seluruh jumlah episode training. Karena lama fase eksplorasi ikut berubah, kelompok ini hanya digunakan untuk menunjukkan pengaruh jadwal epsilon relatif terhadap total episode; bukan pembandingan durasi training final.
#
# Setiap titik melatih ulang lima seed dari awal dengan graf, reward, penyaringan ruas legal, state, dan evaluasi greedy yang sama. Total beban kelompok ini adalah 5 seed × (30.000 + 40.000 + 50.000 + 75.000) = 975.000 episode.

# %% [markdown]
# ### 2.1 Training 30.000 episode

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_30000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=30_000,
    result_subdir='sensitivitas_episode_30000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 30,000 episode
# Jadwal epsilon: dinamis mengikuti total episode eksperimen
# seed=0: over_distance, 5.66 km, is_loop=False
# seed=1: over_distance, 5.52 km, is_loop=False
# seed=2: over_distance, 5.54 km, is_loop=False
# seed=3: no_available_action, 5.03 km, is_loop=False
# seed=4: over_distance, 5.54 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5664.891788     5515.20405    5538.051009
# absolute_distance_error_m      664.891788      515.20405     538.051009
# total_reward                   -86.991574    -109.943815    -149.080475
# mean_comfort                     0.637028       0.701505       0.693007
# return_progress_ratio            0.244444       0.156863       0.313433
# distance_to_start_at_end_m    2445.557024    1948.353176    2135.289769
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                          3              4
# is_loop                                   False          False
# total_distance_m                    5034.938765    5543.346625
# absolute_distance_error_m             34.938765     543.346625
# total_reward                         -87.800702     -76.609628
# mean_comfort                           0.714465       0.704004
# return_progress_ratio                  0.243243       0.326531
# distance_to_start_at_end_m          2334.220843    1354.045636
# closing_action_available                  False          False
# termination_reason          no_available_action  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 3
# Metrik: is_loop=False, jarak=5034.94 m, galat=34.94 m, comfort=0.714, return_progress=0.243, jarak akhir ke start=2334.22 m, terminasi=no_available_action
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4f84281263dd2458dcc1e0cf0e314e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4f84281263dd2458dcc1e0cf0e314e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4f84281263dd2458dcc1e0cf0e314e7 = L.map(
#                 &quot;map_b4f84281263dd2458dcc1e0cf0e314e7&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b4f84281263dd2458dcc1e0cf0e314e7);
#
#
#
#
#
#             var tile_layer_6193cedc56bdc70c5ebc75fcb3dd529b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6193cedc56bdc70c5ebc75fcb3dd529b.addTo(map_b4f84281263dd2458dcc1e0cf0e314e7);
#
#
#             var poly_line_6216788d406a5a626c8a02ce574509e7 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281896899999991, 112.7087177], [-7.281887599999994, 112.708668], [-7.281864900000004, 112.7085983]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_b4f84281263dd2458dcc1e0cf0e314e7);
#
#
#             poly_line_6216788d406a5a626c8a02ce574509e7.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_18932f144e641220225cc1d3c02cafd2 = L.polyline(
#                 [[-7.281864900000004, 112.7085983], [-7.281595399999992, 112.7086674], [-7.281532099999991, 112.7086851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_b4f84281263dd2458dcc1e0cf0e314e7);
#
#
#             poly_line_18932f144e641220225cc1d3c02cafd2.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_1f03a805c971eb4026c0c381f318abca = L.polyline(
#                 [[-7.281532099999991, 112.7086851], [-7.281107699999999, 112.7087868]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_b4f84281263dd2458dcc1e0cf0e314e7);
#
#
#             poly_line_1f03a805c971eb4026c0c381f318abca.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_d848d05fe09a25a6134b9ab4ae2c07c2 = L.polyline(
#                 [[-7.281107699999999, 112.7087868], [-7.281525399999994, 112.7101872]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_b4f84281263dd2458dcc1e0cf0e3
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_30000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 2.2 Training 40.000 episode

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_40000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=40_000,
    result_subdir='sensitivitas_episode_40000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 40,000 episode
# Jadwal epsilon: dinamis mengikuti total episode eksperimen
# seed=0: over_distance, 5.50 km, is_loop=False
# seed=1: over_distance, 5.54 km, is_loop=False
# seed=2: over_distance, 5.58 km, is_loop=False
# seed=3: over_distance, 5.53 km, is_loop=False
# seed=4: over_distance, 5.50 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5502.386202    5539.984339    5576.142016
# absolute_distance_error_m      502.386202     539.984339     576.142016
# total_reward                  -139.655223    -131.195133     -88.454168
# mean_comfort                     0.713633       0.702448       0.737618
# return_progress_ratio            0.174603        0.37037       0.295455
# distance_to_start_at_end_m     1597.47819    2136.484257    1746.837824
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5527.388219    5503.370156
# absolute_distance_error_m      527.388219     503.370156
# total_reward                   -47.145742    -156.212271
# mean_comfort                     0.736259       0.703177
# return_progress_ratio            0.415094       0.421053
# distance_to_start_at_end_m    1622.658431    2089.301496
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 0
# Metrik: is_loop=False, jarak=5502.39 m, galat=502.39 m, comfort=0.714, return_progress=0.175, jarak akhir ke start=1597.48 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3feefb20ef422a68e8a4037d6aae3db1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3feefb20ef422a68e8a4037d6aae3db1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3feefb20ef422a68e8a4037d6aae3db1 = L.map(
#                 &quot;map_3feefb20ef422a68e8a4037d6aae3db1&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3feefb20ef422a68e8a4037d6aae3db1);
#
#
#
#
#
#             var tile_layer_10eaddca4be6b6388f0790f595bcd36d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10eaddca4be6b6388f0790f595bcd36d.addTo(map_3feefb20ef422a68e8a4037d6aae3db1);
#
#
#             var poly_line_8818bd535efb6835936c2b46cba8b945 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281896899999991, 112.7087177], [-7.281887599999994, 112.708668], [-7.281864900000004, 112.7085983]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_3feefb20ef422a68e8a4037d6aae3db1);
#
#
#             poly_line_8818bd535efb6835936c2b46cba8b945.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_ade283b5dfe46213e62e3ee49ac991af = L.polyline(
#                 [[-7.281864900000004, 112.7085983], [-7.282169199999994, 112.7085307]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_3feefb20ef422a68e8a4037d6aae3db1);
#
#
#             poly_line_ade283b5dfe46213e62e3ee49ac991af.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_1fdd06ba82a030e30b70796d27dae728 = L.polyline(
#                 [[-7.282169199999994, 112.7085307], [-7.2821397999999995, 112.7083571]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_3feefb20ef422a68e8a4037d6aae3db1);
#
#
#             poly_line_1fdd06ba82a030e30b70796d27dae728.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_bd742a9fda9438eb204bb9e1c7dab6a0 = L.polyline(
#                 [[-7.2821397999999995, 112.7083571], [-7.282323000000005, 112.7083138], [-7.282782399999992, 112.7082118], [-7.2827919999999935, 112.708215], [-7.282798500000004, 112.7082239], [-7.282803400000003, 112.708233], [-7.282838500000006, 112.70837500000002]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opaci
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_40000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 2.3 Training 50.000 episode

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_50000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=50_000,
    result_subdir='sensitivitas_episode_50000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 50,000 episode
# Jadwal epsilon: dinamis mengikuti total episode eksperimen
# seed=0: over_distance, 5.60 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.52 km, is_loop=False
# seed=3: over_distance, 5.51 km, is_loop=False
# seed=4: over_distance, 5.60 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5598.521483    5511.675315    5517.275918
# absolute_distance_error_m      598.521483     511.675315     517.275918
# total_reward                   -74.970748     -76.940963    -133.848368
# mean_comfort                     0.730868       0.720767       0.755886
# return_progress_ratio             0.26087       0.258621           0.46
# distance_to_start_at_end_m    1452.149463    1135.978365    1593.843056
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5505.994521    5600.680616
# absolute_distance_error_m      505.994521     600.680616
# total_reward                    -61.31648     -87.449833
# mean_comfort                     0.700994       0.651502
# return_progress_ratio                0.26            0.2
# distance_to_start_at_end_m    1685.626997    2598.648799
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 3
# Metrik: is_loop=False, jarak=5505.99 m, galat=505.99 m, comfort=0.701, return_progress=0.260, jarak akhir ke start=1685.63 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51e1fb9e8d638b3eb35be89b5480df9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51e1fb9e8d638b3eb35be89b5480df9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51e1fb9e8d638b3eb35be89b5480df9c = L.map(
#                 &quot;map_51e1fb9e8d638b3eb35be89b5480df9c&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_51e1fb9e8d638b3eb35be89b5480df9c);
#
#
#
#
#
#             var tile_layer_46ad272554f3cdca29599e8451a4f0e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46ad272554f3cdca29599e8451a4f0e8.addTo(map_51e1fb9e8d638b3eb35be89b5480df9c);
#
#
#             var poly_line_f48f71ed04cf8a0be705743f1163951f = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_51e1fb9e8d638b3eb35be89b5480df9c);
#
#
#             poly_line_f48f71ed04cf8a0be705743f1163951f.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_3c78d49df55e01f108e30b861b60d144 = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_51e1fb9e8d638b3eb35be89b5480df9c);
#
#
#             poly_line_3c78d49df55e01f108e30b861b60d144.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_2dc208970638fefbd0741fef1c75a126 = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.283325800000009, 112.7096456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_51e1fb9e8d638b3eb35be89b5480df9c);
#
#
#             poly_line_2dc208970638fefbd0741fef1c75a126.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_8b54f2eed50530beaa2a61f5f9d1eb5e = L.polyline(
#                 [[-7.283325800000009, 112.7096456], [-7.2829505, 112.7084163], [-7.282942300000005, 112.7083891], [-7.282935600000001, 112.7083576]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_51e1fb9e8d638b3e
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_50000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 2.4 Training 75.000 episode

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_75000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=75_000,
    result_subdir='sensitivitas_episode_75000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 75,000 episode
# Jadwal epsilon: dinamis mengikuti total episode eksperimen
# seed=0: over_distance, 5.52 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: no_available_action, 4.99 km, is_loop=False
# seed=3: over_distance, 5.52 km, is_loop=False
# seed=4: over_distance, 5.72 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1                    2  \
# is_loop                             False          False                False
# total_distance_m               5523.30827    5514.605687          4988.268392
# absolute_distance_error_m       523.30827     514.605687            11.731608
# total_reward                   -77.519841     -40.003882           -80.132286
# mean_comfort                      0.67854       0.697658             0.710593
# return_progress_ratio            0.347826       0.482759             0.195652
# distance_to_start_at_end_m    1196.917292    1117.073296          2376.945214
# closing_action_available            False          False                False
# termination_reason          over_distance  over_distance  no_available_action
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5515.968372    5723.967223
# absolute_distance_error_m      515.968372     723.967223
# total_reward                   -75.305796    -102.412537
# mean_comfort                     0.732033       0.692191
# return_progress_ratio            0.444444       0.210526
# distance_to_start_at_end_m    1906.452196    2428.813836
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 2
# Metrik: is_loop=False, jarak=4988.27 m, galat=11.73 m, comfort=0.711, return_progress=0.196, jarak akhir ke start=2376.95 m, terminasi=no_available_action
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06b3fe6d89352f2b5519fae865eab31e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06b3fe6d89352f2b5519fae865eab31e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06b3fe6d89352f2b5519fae865eab31e = L.map(
#                 &quot;map_06b3fe6d89352f2b5519fae865eab31e&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_06b3fe6d89352f2b5519fae865eab31e);
#
#
#
#
#
#             var tile_layer_cb884a1963fcf042d8f17bd87d044499 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb884a1963fcf042d8f17bd87d044499.addTo(map_06b3fe6d89352f2b5519fae865eab31e);
#
#
#             var poly_line_531e0d6e7765153616be19e897f4ded7 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_06b3fe6d89352f2b5519fae865eab31e);
#
#
#             poly_line_531e0d6e7765153616be19e897f4ded7.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_c18c5db83e6614c78f40d92037587654 = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_06b3fe6d89352f2b5519fae865eab31e);
#
#
#             poly_line_c18c5db83e6614c78f40d92037587654.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_1ad43bf78b07df9464ea1658bf85b37b = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.283325800000009, 112.7096456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_06b3fe6d89352f2b5519fae865eab31e);
#
#
#             poly_line_1ad43bf78b07df9464ea1658bf85b37b.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_dfdfdfbbb90e1aec31e33a584bfe185f = L.polyline(
#                 [[-7.283325800000009, 112.7096456], [-7.2829505, 112.7084163], [-7.282942300000005, 112.7083891], [-7.282935600000001, 112.7083576]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_06b3fe6d89352f2b
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_episode_75000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 2.5 Ringkasan epsilon decay dinamis
#
# Tabel dan grafik menggunakan evaluasi greedy lima seed pada setiap jumlah episode. Bandingkan terutama keberhasilan loop, galat jarak, konsistensi bergerak mendekati start, dan peluang closing action tersedia.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Epsilon turun sepanjang total episode masing-masing percobaan.
# Ringkasan ini adalah eksperimen pendahuluan, bukan dasar perbandingan final.
dynamic_decay_results = {
    30_000: result_a_30000,
    40_000: result_a_40000,
    50_000: result_a_50000,
    75_000: result_a_75000,
}

summary_rows = []
for episodes, result in dynamic_decay_results.items():
    metrics = result['metrics']
    summary_rows.append({
        'episodes': episodes,
        'epsilon_decay_episodes': result['epsilon_decay_episodes'],
        'success_rate_greedy': metrics['is_loop'].mean(),
        'mean_distance_error_m': metrics['absolute_distance_error_m'].mean(),
        'mean_total_reward': metrics['total_reward'].mean(),
        'mean_comfort': metrics['mean_comfort'].mean(),
        'mean_return_progress_ratio': metrics['return_progress_ratio'].mean(),
        'closing_action_available_rate': metrics['closing_action_available'].mean(),
    })

dynamic_decay_sensitivity_df = pd.DataFrame(summary_rows).sort_values('episodes')
display(dynamic_decay_sensitivity_df)

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
plots = [
    ('success_rate_greedy', 'Keberhasilan Loop pada Evaluasi Greedy', 'Proporsi seed'),
    ('mean_distance_error_m', 'Rata-rata Galat Jarak', 'Meter'),
    ('mean_return_progress_ratio', 'Konsistensi Bergerak Mendekati Start', 'Proporsi langkah'),
    ('closing_action_available_rate', 'Peluang Closing Action Tersedia', 'Proporsi seed'),
]
for axis, (column, title, ylabel) in zip(axes.flat, plots):
    axis.plot(dynamic_decay_sensitivity_df['episodes'], dynamic_decay_sensitivity_df[column], marker='o')
    axis.set(title=title, xlabel='Jumlah episode training', ylabel=ylabel)
    axis.grid(alpha=0.25)
plt.tight_layout()
plt.show()
# Out:
#    episodes epsilon_decay_episodes  success_rate_greedy  \
# 0     30000                   None                  0.0
# 1     40000                   None                  0.0
# 2     50000                   None                  0.0
# 3     75000                   None                  0.0
#
#    mean_distance_error_m  mean_total_reward  mean_comfort  \
# 0             459.286447        -102.085239      0.690002
# 1             529.854186        -112.532507      0.718627
# 2             546.829571         -86.905278      0.712003
# 3             457.916232         -75.074868      0.702203
#
#    mean_return_progress_ratio  closing_action_available_rate
# 0                    0.256903                            0.0
# 1                    0.335315                            0.0
# 2                    0.287898                            0.0
# 3                    0.336242                            0.0

# %% [markdown]
# ## 3. Eksperimen utama: epsilon decay tetap 50.000 episode
#
# Bagian ini menguji Scenario A pada 50.000, 75.000, 100.000, dan 150.000 episode. Epsilon turun dari 1,00 ke 0,05 hanya selama 50.000 episode pertama, lalu tetap 0,05 sampai training selesai. Dengan demikian, tambahan durasi setelah 50k dapat dibaca sebagai fase perbaikan kebijakan pada tingkat eksplorasi minimum yang sama.
#
# Setiap titik melatih ulang lima seed dari awal. Training 50k dijalankan ulang agar kelompok ini mandiri, walaupun jadwal epsilon-nya secara matematis sama dengan eksperimen dinamis 50k. Total beban kelompok ini adalah 5 seed × (50.000 + 75.000 + 100.000 + 150.000) = 1.875.000 episode.

# %% [markdown]
# ### 3.1 Training 50.000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_fixed_50000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=50_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_50000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 50,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.60 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.52 km, is_loop=False
# seed=3: over_distance, 5.51 km, is_loop=False
# seed=4: over_distance, 5.60 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5598.521483    5511.675315    5517.275918
# absolute_distance_error_m      598.521483     511.675315     517.275918
# total_reward                   -74.970748     -76.940963    -133.848368
# mean_comfort                     0.730868       0.720767       0.755886
# return_progress_ratio             0.26087       0.258621           0.46
# distance_to_start_at_end_m    1452.149463    1135.978365    1593.843056
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5505.994521    5600.680616
# absolute_distance_error_m      505.994521     600.680616
# total_reward                    -61.31648     -87.449833
# mean_comfort                     0.700994       0.651502
# return_progress_ratio                0.26            0.2
# distance_to_start_at_end_m    1685.626997    2598.648799
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 3
# Metrik: is_loop=False, jarak=5505.99 m, galat=505.99 m, comfort=0.701, return_progress=0.260, jarak akhir ke start=1685.63 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4c26e7d9cf3aa07237763138b703618 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4c26e7d9cf3aa07237763138b703618&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4c26e7d9cf3aa07237763138b703618 = L.map(
#                 &quot;map_e4c26e7d9cf3aa07237763138b703618&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e4c26e7d9cf3aa07237763138b703618);
#
#
#
#
#
#             var tile_layer_d9516e64a39ff37b7f46347eb4d8469b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9516e64a39ff37b7f46347eb4d8469b.addTo(map_e4c26e7d9cf3aa07237763138b703618);
#
#
#             var poly_line_d5f7ff2c362d7b260199d9c244c080e3 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.282627399999991, 112.70984980000001]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_e4c26e7d9cf3aa07237763138b703618);
#
#
#             poly_line_d5f7ff2c362d7b260199d9c244c080e3.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_65c29bb5bff27afea659d66127d357d0 = L.polyline(
#                 [[-7.282627399999991, 112.70984980000001], [-7.282767399999995, 112.70980800000001], [-7.282977699999998, 112.709747]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_e4c26e7d9cf3aa07237763138b703618);
#
#
#             poly_line_65c29bb5bff27afea659d66127d357d0.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_be1916f37232a008eeaa5d7a601ae791 = L.polyline(
#                 [[-7.282977699999998, 112.709747], [-7.283325800000009, 112.7096456]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_e4c26e7d9cf3aa07237763138b703618);
#
#
#             poly_line_be1916f37232a008eeaa5d7a601ae791.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_9c594da46f6626b796069bee41384c3c = L.polyline(
#                 [[-7.283325800000009, 112.7096456], [-7.2829505, 112.7084163], [-7.282942300000005, 112.7083891], [-7.282935600000001, 112.7083576]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_e4c26e7d9cf3aa07
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_50000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.2 Training 75.000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_fixed_75000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=75_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_75000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 75,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.55 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.50 km, is_loop=False
# seed=3: over_distance, 5.50 km, is_loop=False
# seed=4: no_available_action, 5.15 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5550.496532    5514.680144    5503.030874
# absolute_distance_error_m      550.496532     514.680144     503.030874
# total_reward                   -86.571918     -80.105101     -93.800084
# mean_comfort                      0.76407       0.677155       0.689035
# return_progress_ratio            0.390244          0.175        0.17284
# distance_to_start_at_end_m    2179.511314    1492.829835    2168.576421
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3                    4
# is_loop                             False                False
# total_distance_m              5500.944203          5153.992069
# absolute_distance_error_m      500.944203           153.992069
# total_reward                   -58.640383           -55.884971
# mean_comfort                     0.742567             0.698921
# return_progress_ratio                 0.2             0.255319
# distance_to_start_at_end_m    1604.431361          1462.311377
# closing_action_available            False                False
# termination_reason          over_distance  no_available_action
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 4
# Metrik: is_loop=False, jarak=5153.99 m, galat=153.99 m, comfort=0.699, return_progress=0.255, jarak akhir ke start=1462.31 m, terminasi=no_available_action
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3f7f4f4bb8c2b369f72a760ce89813e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3f7f4f4bb8c2b369f72a760ce89813e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3f7f4f4bb8c2b369f72a760ce89813e = L.map(
#                 &quot;map_a3f7f4f4bb8c2b369f72a760ce89813e&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a3f7f4f4bb8c2b369f72a760ce89813e);
#
#
#
#
#
#             var tile_layer_c28665e2edd67e6e497502e537e285df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c28665e2edd67e6e497502e537e285df.addTo(map_a3f7f4f4bb8c2b369f72a760ce89813e);
#
#
#             var poly_line_c789ee57e5e169b9b0ae7f28c22e6a91 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281896899999991, 112.7087177], [-7.281887599999994, 112.708668], [-7.281864900000004, 112.7085983]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_a3f7f4f4bb8c2b369f72a760ce89813e);
#
#
#             poly_line_c789ee57e5e169b9b0ae7f28c22e6a91.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_00f42948b2c394c057e78ef8eec9cfcd = L.polyline(
#                 [[-7.281864900000004, 112.7085983], [-7.282169199999994, 112.7085307]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_a3f7f4f4bb8c2b369f72a760ce89813e);
#
#
#             poly_line_00f42948b2c394c057e78ef8eec9cfcd.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_493df3a20806a070b8a581256d542036 = L.polyline(
#                 [[-7.282169199999994, 112.7085307], [-7.2821397999999995, 112.7083571]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_a3f7f4f4bb8c2b369f72a760ce89813e);
#
#
#             poly_line_493df3a20806a070b8a581256d542036.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_9d3664d35b18d668bebecca79a8837de = L.polyline(
#                 [[-7.2821397999999995, 112.7083571], [-7.282323000000005, 112.7083138], [-7.282782399999992, 112.7082118], [-7.2827919999999935, 112.708215], [-7.282798500000004, 112.7082239], [-7.282803400000003, 112.708233], [-7.282838500000006, 112.70837500000002]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opaci
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_75000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.3 Training 100.000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_fixed_100000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=100_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_100000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 100,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: over_distance, 5.73 km, is_loop=False
# seed=1: over_distance, 5.51 km, is_loop=False
# seed=2: over_distance, 5.53 km, is_loop=False
# seed=3: over_distance, 5.52 km, is_loop=False
# seed=4: over_distance, 5.54 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                    0              1              2  \
# is_loop                             False          False          False
# total_distance_m              5732.485047     5510.75518    5531.362393
# absolute_distance_error_m      732.485047      510.75518     531.362393
# total_reward                  -261.091273     -40.743483     -79.355164
# mean_comfort                      0.71793       0.698874       0.690386
# return_progress_ratio             0.54717       0.489796       0.101449
# distance_to_start_at_end_m     662.510729     124.594023    2911.277973
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
#
# seed                                    3              4
# is_loop                             False          False
# total_distance_m              5524.234762    5536.999203
# absolute_distance_error_m      524.234762     536.999203
# total_reward                   -52.042215     -58.972988
# mean_comfort                     0.734298       0.729398
# return_progress_ratio                0.75       0.316667
# distance_to_start_at_end_m     374.587921    1165.840124
# closing_action_available            False          False
# termination_reason          over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 1
# Metrik: is_loop=False, jarak=5510.76 m, galat=510.76 m, comfort=0.699, return_progress=0.490, jarak akhir ke start=124.59 m, terminasi=over_distance
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31083e512fbd00567a4b852836558417 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31083e512fbd00567a4b852836558417&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31083e512fbd00567a4b852836558417 = L.map(
#                 &quot;map_31083e512fbd00567a4b852836558417&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_31083e512fbd00567a4b852836558417);
#
#
#
#
#
#             var tile_layer_9df6bae112a77b47bca682abfef8df3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9df6bae112a77b47bca682abfef8df3d.addTo(map_31083e512fbd00567a4b852836558417);
#
#
#             var poly_line_d32d1d59e950d4721c983e343b5ff4e2 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281896899999991, 112.7087177], [-7.281887599999994, 112.708668], [-7.281864900000004, 112.7085983]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_31083e512fbd00567a4b852836558417);
#
#
#             poly_line_d32d1d59e950d4721c983e343b5ff4e2.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_0c89f72b648d9f0253f8957030504d6a = L.polyline(
#                 [[-7.281864900000004, 112.7085983], [-7.281595399999992, 112.7086674], [-7.281532099999991, 112.7086851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_31083e512fbd00567a4b852836558417);
#
#
#             poly_line_0c89f72b648d9f0253f8957030504d6a.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_9934bf5be82d81b04891e21941385da2 = L.polyline(
#                 [[-7.281532099999991, 112.7086851], [-7.281107699999999, 112.7087868]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_31083e512fbd00567a4b852836558417);
#
#
#             poly_line_9934bf5be82d81b04891e21941385da2.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_c2bdcd9bc6c963cde3aa1ee54301e8ea = L.polyline(
#                 [[-7.281107699999999, 112.7087868], [-7.2810654, 112.7086208]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_31083e512fbd00567a4b852836558417);
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_100000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.4 Training 150.000 episode dengan epsilon decay 50.000

# %%
import importlib
# Memuat ulang core agar notebook memakai fungsi dan parameter terbaru.
importlib.reload(rute_lari_core)

result_a_fixed_150000 = rute_lari_core.run_scenario_experiment(
    G, START_NODE, 'A',
    episodes=150_000,
    # Epsilon turun hanya pada 50.000 episode pertama, kemudian tetap 0,05.
    epsilon_decay_episodes=50_000,
    result_subdir='sensitivitas_epsilon_tetap_50000_episode_150000_A',
)
# Out:
# Menjalankan Scenario A: 5 seed x 150,000 episode
# Jadwal epsilon: turun selama 50,000 episode, lalu tetap 0.05
# seed=0: no_available_action, 1.59 km, is_loop=False
# seed=1: no_available_action, 5.38 km, is_loop=False
# seed=2: over_distance, 5.55 km, is_loop=False
# seed=3: over_distance, 5.52 km, is_loop=False
# seed=4: over_distance, 5.58 km, is_loop=False
# Tampilan vertikal metrik evaluasi utama per seed
# seed                                          0                    1  \
# is_loop                                   False                False
# total_distance_m                    1591.969347          5382.736783
# absolute_distance_error_m           3408.030653           382.736783
# total_reward                         -42.667766           -90.999139
# mean_comfort                            0.71566             0.674418
# return_progress_ratio                       NaN             0.147059
# distance_to_start_at_end_m           386.410849          3384.929471
# closing_action_available                  False                False
# termination_reason          no_available_action  no_available_action
#
# seed                                    2              3              4
# is_loop                             False          False          False
# total_distance_m              5545.606141    5520.525309    5582.947246
# absolute_distance_error_m      545.606141     520.525309     582.947246
# total_reward                   -55.975124     -61.128059     -40.198052
# mean_comfort                     0.691221       0.706386       0.737262
# return_progress_ratio             0.44186       0.116279       0.355556
# distance_to_start_at_end_m     609.756402    2036.111034    2013.714024
# closing_action_available            False          False          False
# termination_reason          over_distance  over_distance  over_distance
# === Q-TABLE / SEED YANG DIPILIH UNTUK PETA ===
# Scenario: A; seed: 1
# Metrik: is_loop=False, jarak=5382.74 m, galat=382.74 m, comfort=0.674, return_progress=0.147, jarak akhir ke start=3384.93 m, terminasi=no_available_action
# Alasan: Tidak ada loop valid, sehingga dipilih rute dengan galat jarak paling kecil; jika setara, jarak akhir ke start paling kecil, comfort tertinggi, lalu return progress tertinggi.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_076725e0decf1aa768ff8f22a03f2631 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_076725e0decf1aa768ff8f22a03f2631&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_076725e0decf1aa768ff8f22a03f2631 = L.map(
#                 &quot;map_076725e0decf1aa768ff8f22a03f2631&quot;,
#                 {
#                     center: [-7.2822471999999925, 112.7099713],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#
#
#
#             var tile_layer_74c69b2014c1e3a78a09c3118db43a53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74c69b2014c1e3a78a09c3118db43a53.addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#             var poly_line_d6b04348536dbe6ec06dc599296ef310 = L.polyline(
#                 [[-7.2822471999999925, 112.7099713], [-7.281918399999998, 112.7100804]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#             poly_line_d6b04348536dbe6ec06dc599296ef310.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_7fcc6c466a42b67b6d83f40ef05d1a95 = L.polyline(
#                 [[-7.281918399999998, 112.7100804], [-7.281575100000001, 112.708849], [-7.281558999999994, 112.7087937], [-7.281532099999991, 112.7086851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#             poly_line_7fcc6c466a42b67b6d83f40ef05d1a95.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_74ad867e924fea71fcfd0034be762bff = L.polyline(
#                 [[-7.281532099999991, 112.7086851], [-7.281107699999999, 112.7087868]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#             poly_line_74ad867e924fea71fcfd0034be762bff.bindTooltip(
#                 `&lt;div&gt;
#                      Segmen KM 0-1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_64383a5172d0110ae5e94f32228b7650 = L.polyline(
#                 [[-7.281107699999999, 112.7087868], [-7.280662099999998, 112.7088851]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2457F5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2457F5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.92, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_076725e0decf1aa768ff8f22a03f2631);
#
#
#             po
# History: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/training_history_A.csv
# Evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/evaluation_metrics_A.csv
# Diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/diagnosis_metrics_A.csv
# Termination rate training: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/termination_rates_training_A.csv
# Termination rate evaluasi: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/termination_rates_evaluation_A.csv
# Grafik training utama: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/grafik_training_A.png
# Grafik diagnosis: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/grafik_diagnosis_A.png
# Peta: /Users/davidprastiyaimannuel/widya_kartika/david-31123022-tugas-akhir/hasil_bab_4/training_qlearning_5km/sensitivitas_epsilon_tetap_50000_episode_150000_A/peta_interaktif_scenario_A.html

# %% [markdown]
# ### 3.5 Ringkasan epsilon decay tetap
#
# Tabel dan grafik menggunakan evaluasi greedy lima seed. Karena seluruh titik memakai horizon decay 50.000 episode yang sama, perbedaan hasil terutama mencerminkan tambahan durasi training. TD-error dibaca dari grafik diagnosis pada masing-masing training.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Semua hasil memakai epsilon yang turun selama 50.000 episode pertama, lalu tetap 0,05.
# Perbedaan antar titik terutama berasal dari tambahan durasi training.
fixed_decay_results = {
    50_000: result_a_fixed_50000,
    75_000: result_a_fixed_75000,
    100_000: result_a_fixed_100000,
    150_000: result_a_fixed_150000,
}

summary_rows = []
for episodes, result in fixed_decay_results.items():
    metrics = result['metrics']
    summary_rows.append({
        'episodes': episodes,
        'epsilon_decay_episodes': result['epsilon_decay_episodes'],
        'success_rate_greedy': metrics['is_loop'].mean(),
        'mean_distance_error_m': metrics['absolute_distance_error_m'].mean(),
        'mean_total_reward': metrics['total_reward'].mean(),
        'mean_comfort': metrics['mean_comfort'].mean(),
        'mean_return_progress_ratio': metrics['return_progress_ratio'].mean(),
        'closing_action_available_rate': metrics['closing_action_available'].mean(),
    })

fixed_decay_sensitivity_df = pd.DataFrame(summary_rows).sort_values('episodes')
display(fixed_decay_sensitivity_df)

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
plots = [
    ('success_rate_greedy', 'Keberhasilan Loop pada Evaluasi Greedy', 'Proporsi seed'),
    ('mean_distance_error_m', 'Rata-rata Galat Jarak', 'Meter'),
    ('mean_return_progress_ratio', 'Konsistensi Bergerak Mendekati Start', 'Proporsi langkah'),
    ('closing_action_available_rate', 'Peluang Closing Action Tersedia', 'Proporsi seed'),
]
for axis, (column, title, ylabel) in zip(axes.flat, plots):
    axis.plot(fixed_decay_sensitivity_df['episodes'], fixed_decay_sensitivity_df[column], marker='o')
    axis.set(title=title, xlabel='Jumlah episode training', ylabel=ylabel)
    axis.grid(alpha=0.25)
plt.tight_layout()
plt.show()
# Out:
#    episodes  epsilon_decay_episodes  success_rate_greedy  \
# 0     50000                   50000                  0.0
# 1     75000                   50000                  0.0
# 2    100000                   50000                  0.0
# 3    150000                   50000                  0.0
#
#    mean_distance_error_m  mean_total_reward  mean_comfort  \
# 0             546.829571         -86.905278      0.712003
# 1             444.628764         -75.000491      0.714349
# 2             567.167317         -98.441025      0.714177
# 3            1087.969227         -58.193628      0.704990
#
#    mean_return_progress_ratio  closing_action_available_rate
# 0                    0.287898                            0.0
# 1                    0.238681                            0.0
# 2                    0.441016                            0.0
# 3                    0.265188                            0.0

# %% [markdown]
# ## 4. Cara membaca hasil evaluasi
#
# Tabel evaluasi utama memuat `is_loop`, `total_distance_m`, `absolute_distance_error_m`, `total_reward`, `mean_comfort`, `return_progress_ratio`, `distance_to_start_at_end_m`, `closing_action_available`, dan `termination_reason`.
#
# Grafik diagnosis tetap membantu menjelaskan proses training, khususnya termination rate dan ketersediaan closing action.
#
# Baca detail seluruh implementasi di `IMPLEMENTASI.md`.
